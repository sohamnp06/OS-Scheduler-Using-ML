# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("../data/dataset_for_model.csv")
df.head()
# Out:
#    num_processes  avg_burst_time  burst_time_variance  short_job_ratio  \
# 0              8        3.875000             3.359375         0.500000
# 1              3       15.000000            14.000000         0.333333
# 2              7       14.571429             9.959184         0.428571
# 3              3       14.000000             4.666667         0.666667
# 4              6       12.000000            44.333333         0.333333
#
#    long_job_ratio  priority_variance  arrival_irregularity  \
# 0        0.500000           5.437500             19.187500
# 1        0.666667           0.222222             16.888889
# 2        0.571429           4.122449             48.693878
# 3        0.333333          14.888889             11.555556
# 4        0.666667           6.666667              7.555556
#
#    burst_time_skewness  arrival_range  max_min_burst_ratio
# 0            -0.059000             15             6.000000
# 1            -0.381802             10             1.900000
# 2            -0.067345             18             1.900000
# 3             0.595170              8             1.416667
# 4            -0.447176              8            20.000000

# %%
df.columns
# Out:
# Index(['num_processes', 'avg_burst_time', 'burst_time_variance',
#        'short_job_ratio', 'long_job_ratio', 'priority_variance',
#        'arrival_irregularity', 'burst_time_skewness', 'arrival_range',
#        'max_min_burst_ratio'],
#       dtype='object')

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')
